# %%
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import mysql.connector
#       2 import pandas as pd
#       4 conn = mysql.connector.connect(
#       5     host="localhost",
#       6     user="analytics_user",
#    (...)
#       9     port=3306
#      10 )
#
# ModuleNotFoundError: No module named 'mysql'
